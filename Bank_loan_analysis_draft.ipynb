# %% [markdown]
# # Summer_school_DSS

# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from pandas import DataFrame as df
from sklearn.preprocessing import StandardScaler

# %%
training_set = pd.read_csv('D:\Jupyter_notebook_projects\Summer_school_DSS_2020\credit_train.csv')
testing_set=pd.read_csv('D:\Jupyter_notebook_projects\Summer_school_DSS_2020\credit_test.csv')

# %%
training_set.head()
# Out:
#                                 Loan ID                           Customer ID  \
# 0  14dd8831-6af5-400b-83ec-68e61888a048  981165ec-3274-42f5-a3b4-d104041a9ca9
# 1  4771cc26-131a-45db-b5aa-537ea4ba5342  2de017a3-2e01-49cb-a581-08169e83be29
# 2  4eed4e6a-aa2f-4c91-8651-ce984ee8fb26  5efb2b2b-bf11-4dfd-a572-3761a2694725
# 3  77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a  e777faab-98ae-45af-9a86-7ce5b33b1011
# 4  d4062e70-befa-4995-8643-a0de73938182  81536ad9-5ccf-4eb8-befb-47a4d608658e
#
#   Loan Status  Current Loan Amount        Term  Credit Score  Annual Income  \
# 0  Fully Paid             445412.0  Short Term         709.0      1167493.0
# 1  Fully Paid             262328.0  Short Term           NaN            NaN
# 2  Fully Paid           99999999.0  Short Term         741.0      2231892.0
# 3  Fully Paid             347666.0   Long Term         721.0       806949.0
# 4  Fully Paid             176220.0  Short Term           NaN            NaN
#
# ...

# %%
training_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100514 entries, 0 to 100513
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Loan ID                       100000 non-null  object
#  1   Customer ID                   100000 non-null  object
#  2   Loan Status                   100000 non-null  object
#  3   Current Loan Amount           100000 non-null  float64
#  4   Term                          100000 non-null  object
#  5   Credit Score                  80846 non-null   float64
#  6   Annual Income                 80846 non-null   float64
#  7   Years in current job          95778 non-null   object
#  8   Home Ownership                100000 non-null  object
#  9   Purpose                       100000 non-null  object
#  10  Monthly Debt                  100000 non-null  float64
#  11  Years of Credit History       100000 non-null  float64
# ...

# %%
cols = ['Loan ID','Customer ID', 'Loan Status','Term','Years in current job', 'Home Ownership', 'Purpose']
training_set[cols] = training_set[cols].replace(',','.', regex=True).astype(float64)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-101-028dfbb0857a> in <module>
#       1 cols = ['Loan ID','Customer ID', 'Loan Status','Term','Years in current job', 'Home Ownership', 'Purpose']
# ----> 2 training_set[cols] = training_set[cols].replace(',','.', regex=True).astype(float64)
#
# D:\Programs\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# D:\Programs\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# ...

# %%
training_set.shape
# Out:
# (100514, 19)

# %%
training_set.describe()
# Out:
#        Current Loan Amount  Credit Score  Annual Income   Monthly Debt  \
# count         1.000000e+05  80846.000000   8.084600e+04  100000.000000
# mean          1.176045e+07   1076.456089   1.378277e+06   18472.412336
# std           3.178394e+07   1475.403791   1.081360e+06   12174.992609
# min           1.080200e+04    585.000000   7.662700e+04       0.000000
# 25%           1.796520e+05    705.000000   8.488440e+05   10214.162500
# 50%           3.122460e+05    724.000000   1.174162e+06   16220.300000
# 75%           5.249420e+05    741.000000   1.650663e+06   24012.057500
# max           1.000000e+08   7510.000000   1.655574e+08  435843.280000
#
#        Years of Credit History  Months since last delinquent  \
# count            100000.000000                  46859.000000
# mean                 18.199141                     34.901321
# std                   7.015324                     21.997829
# min                   3.600000                      0.000000
# ...

# %% [markdown]
# #comment on describe

# %%
training_set.columns
# Out:
# Index(['Loan ID', 'Customer ID', 'Loan Status', 'Current Loan Amount', 'Term',
#        'Credit Score', 'Annual Income', 'Years in current job',
#        'Home Ownership', 'Purpose', 'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
unique_values =  pd.unique('training_set')

# %%
training_set_df = pd.DataFrame(training_set)

# %%
training_set_df.rename(columns = {'Loan ID':'Loan_ID', 'Customer ID':'Customer_ID', 'Loan Status':'Loan_Status', 'Current Loan Amount':'Current_Loan_Amount', 'Credit Score':'Credit_Score','Annual income':'Annual_income','Years in current job':'Years_in_current_job','Home Ownership':'Home_Ownership','Monthly Debt':'Monthly_Debt','Years of Credit History':'Years_of_Credit_History','Months since last delinquent':'Months_since_last_delinquent','Number of Open Accounts':'Number_of_Open_Accounts','Number of Credit Problems':'Number_of_Credit_Problems','Current Credit Balance':'Current_Credit_Balance','Maximum Open Credit':'Maximum_Open_Credit','Tax Liens':'Tax_Liens'}, inplace = True)

# %%
training_set.corr()
# Out:
#                               Current Loan Amount  Credit Score  \
# Current Loan Amount                      1.000000     -0.096652
# Credit Score                            -0.096652      1.000000
# Annual Income                            0.013112     -0.017078
# Monthly Debt                            -0.006643     -0.001674
# Years of Credit History                  0.019282     -0.009720
# Months since last delinquent             0.011248     -0.003739
# Number of Open Accounts                  0.001478      0.006435
# Number of Credit Problems               -0.002795     -0.003022
# Current Credit Balance                   0.003880     -0.000104
# Maximum Open Credit                     -0.001271     -0.002827
# Bankruptcies                            -0.000608     -0.006935
# Tax Liens                               -0.002048      0.005146
#
#                               Annual Income  Monthly Debt  \
# Current Loan Amount                0.013112     -0.006643
# ...

# %%
training_set.isna().sum()
# Out:
# Loan ID                           514
# Customer ID                       514
# Loan Status                       514
# Current Loan Amount               514
# Term                              514
# Credit Score                    19668
# Annual Income                   19668
# Years in current job             4736
# Home Ownership                    514
# Purpose                           514
# Monthly Debt                      514
# Years of Credit History           514
# Months since last delinquent    53655
# Number of Open Accounts           514
# Number of Credit Problems         514
# Current Credit Balance            514
# Maximum Open Credit               516
# Bankruptcies                      718
# Tax Liens                         524
# dtype: int64

# %%
training_set.isnull().sum()
# Out:
# Loan ID                           514
# Customer ID                       514
# Loan Status                       514
# Current Loan Amount               514
# Term                              514
# Credit Score                    19668
# Annual Income                   19668
# Years in current job             4736
# Home Ownership                    514
# Purpose                           514
# Monthly Debt                      514
# Years of Credit History           514
# Months since last delinquent    53655
# Number of Open Accounts           514
# Number of Credit Problems         514
# Current Credit Balance            514
# Maximum Open Credit               516
# Bankruptcies                      718
# Tax Liens                         524
# dtype: int64

# %%
training_set.notnull().sum()
# Out:
# Loan ID                         100000
# Customer ID                     100000
# Loan Status                     100000
# Current Loan Amount             100000
# Term                            100000
# Credit Score                     80846
# Annual Income                    80846
# Years in current job             95778
# Home Ownership                  100000
# Purpose                         100000
# Monthly Debt                    100000
# Years of Credit History         100000
# Months since last delinquent     46859
# Number of Open Accounts         100000
# Number of Credit Problems       100000
# Current Credit Balance          100000
# Maximum Open Credit              99998
# Bankruptcies                     99796
# Tax Liens                        99990
# dtype: int64

# %%
training_set.isna().sum()
# Out:
# Loan ID                           514
# Customer ID                       514
# Loan Status                       514
# Current Loan Amount               514
# Term                              514
# Credit Score                    19668
# Annual Income                   19668
# Years in current job             4736
# Home Ownership                    514
# Purpose                           514
# Monthly Debt                      514
# Years of Credit History           514
# Months since last delinquent    53655
# Number of Open Accounts           514
# Number of Credit Problems         514
# Current Credit Balance            514
# Maximum Open Credit               516
# Bankruptcies                      718
# Tax Liens                         524
# dtype: int64

# %%
training_set.tail()
# Out:
#        Loan ID Customer ID Loan Status  Current Loan Amount Term  \
# 100509     NaN         NaN         NaN                  NaN  NaN
# 100510     NaN         NaN         NaN                  NaN  NaN
# 100511     NaN         NaN         NaN                  NaN  NaN
# 100512     NaN         NaN         NaN                  NaN  NaN
# 100513     NaN         NaN         NaN                  NaN  NaN
#
#         Credit Score  Annual Income Years in current job Home Ownership  \
# 100509           NaN            NaN                  NaN            NaN
# 100510           NaN            NaN                  NaN            NaN
# 100511           NaN            NaN                  NaN            NaN
# 100512           NaN            NaN                  NaN            NaN
# 100513           NaN            NaN                  NaN            NaN
#
#        Purpose  Monthly Debt  Years of Credit History  \
# 100509     NaN           NaN                      NaN
# ...

# %%
training_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100514 entries, 0 to 100513
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Loan ID                       100000 non-null  object
#  1   Customer ID                   100000 non-null  object
#  2   Loan Status                   100000 non-null  object
#  3   Current Loan Amount           100000 non-null  float64
#  4   Term                          100000 non-null  object
#  5   Credit Score                  80846 non-null   float64
#  6   Annual Income                 80846 non-null   float64
#  7   Years in current job          95778 non-null   object
#  8   Home Ownership                100000 non-null  object
#  9   Purpose                       100000 non-null  object
#  10  Monthly Debt                  100000 non-null  float64
#  11  Years of Credit History       100000 non-null  float64
# ...

# %%
### Interesting point here is that Credit score and Annual income seems to be linked.

# %%
#calculate_null_values(training_set)

# %%
#10 000 for validation
#prediction for each of the casses on the test set

# %%
training_set.head()
# Out:
#                                 Loan ID                           Customer ID  \
# 0  14dd8831-6af5-400b-83ec-68e61888a048  981165ec-3274-42f5-a3b4-d104041a9ca9
# 1  4771cc26-131a-45db-b5aa-537ea4ba5342  2de017a3-2e01-49cb-a581-08169e83be29
# 2  4eed4e6a-aa2f-4c91-8651-ce984ee8fb26  5efb2b2b-bf11-4dfd-a572-3761a2694725
# 3  77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a  e777faab-98ae-45af-9a86-7ce5b33b1011
# 4  d4062e70-befa-4995-8643-a0de73938182  81536ad9-5ccf-4eb8-befb-47a4d608658e
#
#   Loan Status  Current Loan Amount        Term  Credit Score  Annual Income  \
# 0  Fully Paid             445412.0  Short Term         709.0      1167493.0
# 1  Fully Paid             262328.0  Short Term           NaN            NaN
# 2  Fully Paid           99999999.0  Short Term         741.0      2231892.0
# 3  Fully Paid             347666.0   Long Term         721.0       806949.0
# 4  Fully Paid             176220.0  Short Term           NaN            NaN
#
# ...

# %%
testing_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10353 entries, 0 to 10352
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Loan ID                       10000 non-null  object
#  1   Customer ID                   10000 non-null  object
#  2   Current Loan Amount           10000 non-null  float64
#  3   Term                          10000 non-null  object
#  4   Credit Score                  8019 non-null   float64
#  5   Annual Income                 8019 non-null   float64
#  6   Years in current job          9573 non-null   object
#  7   Home Ownership                10000 non-null  object
#  8   Purpose                       10000 non-null  object
#  9   Monthly Debt                  10000 non-null  float64
#  10  Years of Credit History       10000 non-null  float64
#  11  Months since last delinquent  4694 non-null   float64
# ...

# %%
testing_set.head()
# Out:
#                                 Loan ID                           Customer ID  \
# 0  f738779f-c726-40dc-92cf-689d73af533d  ded0b3c3-6bf4-4091-8726-47039f2c1b90
# 1  6dcc0947-164d-476c-a1de-3ae7283dde0a  1630e6e3-34e3-461a-8fda-09297d3140c8
# 2  f7744d01-894b-49c3-8777-fc6431a2cff1  2c60938b-ad2b-4702-804d-eeca43949c52
# 3  83721ffb-b99a-4a0f-aea5-ef472a138b41  12116614-2f3c-4d16-ad34-d92883718806
# 4  08f3789f-5714-4b10-929d-e1527ab5e5a3  39888105-fd5f-4023-860a-30a3e6f5ccb7
#
#    Current Loan Amount        Term  Credit Score  Annual Income  \
# 0             611314.0  Short Term         747.0      2074116.0
# 1             266662.0  Short Term         734.0      1919190.0
# 2             153494.0  Short Term         709.0       871112.0
# 3             176242.0  Short Term         727.0       780083.0
# 4             321992.0  Short Term         744.0      1761148.0
#
#   Years in current job Home Ownership             Purpose  Monthly Debt  \
# ...

# %%
testing_set.isna().sum()
# Out:
# Loan ID                          353
# Customer ID                      353
# Current Loan Amount              353
# Term                             353
# Credit Score                    2334
# Annual Income                   2334
# Years in current job             780
# Home Ownership                   353
# Purpose                          353
# Monthly Debt                     353
# Years of Credit History          353
# Months since last delinquent    5659
# Number of Open Accounts          353
# Number of Credit Problems        353
# Current Credit Balance           353
# Maximum Open Credit              353
# Bankruptcies                     375
# Tax Liens                        354
# dtype: int64

# %%
testing_set.tail()
# Out:
#       Loan ID Customer ID  Current Loan Amount Term  Credit Score  \
# 10348     NaN         NaN                  NaN  NaN           NaN
# 10349     NaN         NaN                  NaN  NaN           NaN
# 10350     NaN         NaN                  NaN  NaN           NaN
# 10351     NaN         NaN                  NaN  NaN           NaN
# 10352     NaN         NaN                  NaN  NaN           NaN
#
#        Annual Income Years in current job Home Ownership Purpose  \
# 10348            NaN                  NaN            NaN     NaN
# 10349            NaN                  NaN            NaN     NaN
# 10350            NaN                  NaN            NaN     NaN
# 10351            NaN                  NaN            NaN     NaN
# 10352            NaN                  NaN            NaN     NaN
#
#        Monthly Debt  Years of Credit History  Months since last delinquent  \
# 10348           NaN                      NaN                           NaN
# ...

# %%
testing_set.shape
# Out:
# (10353, 18)

# %%
training_set.shape
# Out:
# (100514, 19)

# %%
training_set.corr()
# Out:
#                               Current Loan Amount  Credit Score  \
# Current Loan Amount                      1.000000     -0.096652
# Credit Score                            -0.096652      1.000000
# Annual Income                            0.013112     -0.017078
# Monthly Debt                            -0.006643     -0.001674
# Years of Credit History                  0.019282     -0.009720
# Months since last delinquent             0.011248     -0.003739
# Number of Open Accounts                  0.001478      0.006435
# Number of Credit Problems               -0.002795     -0.003022
# Current Credit Balance                   0.003880     -0.000104
# Maximum Open Credit                     -0.001271     -0.002827
# Bankruptcies                            -0.000608     -0.006935
# Tax Liens                               -0.002048      0.005146
#
#                               Annual Income  Monthly Debt  \
# Current Loan Amount                0.013112     -0.006643
# ...

# %%
training_set.drop(labels=['Loan ID', 'Customer ID'], axis=1, inplace=True)

# %%
plt.figure(figsize=(20,10))
sns.heatmap(training_set.corr(), annot = True)

# %%
training_set_reduced = training_set.dropna()

# %%
training_set_reduced
# Out:
#       Loan Status  Current Loan Amount        Term  Credit Score  \
# 2      Fully Paid           99999999.0  Short Term         741.0
# 6      Fully Paid             217646.0  Short Term         730.0
# 8      Fully Paid             548746.0  Short Term         678.0
# 10     Fully Paid           99999999.0  Short Term         728.0
# 12     Fully Paid           99999999.0  Short Term         740.0
# ...           ...                  ...         ...           ...
# 99990  Fully Paid           99999999.0  Short Term         742.0
# 99993  Fully Paid              44484.0  Short Term         717.0
# 99994  Fully Paid             210584.0  Short Term         719.0
# 99996  Fully Paid           99999999.0  Short Term         732.0
# 99997  Fully Paid             103136.0  Short Term         742.0
#
#        Annual Income Years in current job Home Ownership             Purpose  \
# 2          2231892.0              8 years       Own Home  Debt Consolidation
# ...

# %%
training_set_reduced.shape
# Out:
# (36423, 17)

# %%
plt.figure(figsize=(25,15))
sns.heatmap(training_set_reduced.corr(), annot = True)

# %%
training_set_reduced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36423 entries, 2 to 99997
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Loan Status                   36423 non-null  object
#  1   Current Loan Amount           36423 non-null  float64
#  2   Term                          36423 non-null  object
#  3   Credit Score                  36423 non-null  float64
#  4   Annual Income                 36423 non-null  float64
#  5   Years in current job          36423 non-null  object
#  6   Home Ownership                36423 non-null  object
#  7   Purpose                       36423 non-null  object
#  8   Monthly Debt                  36423 non-null  float64
#  9   Years of Credit History       36423 non-null  float64
#  10  Months since last delinquent  36423 non-null  float64
#  11  Number of Open Accounts       36423 non-null  float64
# ...

# %%
tr_set_high_CS = training_set[training_set['Credit Score']>800]

# %%
tr_set_high_CS
# Out:
#        Loan Status  Current Loan Amount        Term  Credit Score  \
# 5      Charged Off             206602.0  Short Term        7290.0
# 43     Charged Off             288948.0  Short Term        7120.0
# 51     Charged Off             219692.0   Long Term        6610.0
# 56     Charged Off              78012.0  Short Term        7380.0
# 65     Charged Off             523908.0   Long Term        7370.0
# ...            ...                  ...         ...           ...
# 99851  Charged Off             198572.0  Short Term        7420.0
# 99872  Charged Off             110924.0  Short Term        7070.0
# 99906  Charged Off             175362.0  Short Term        6880.0
# 99944  Charged Off              88968.0  Short Term        6790.0
# 99947  Charged Off             205458.0   Long Term        6940.0
#
#        Annual Income Years in current job Home Ownership             Purpose  \
# 5           896857.0            10+ years  Home Mortgage  Debt Consolidation
# ...

# %%
sns.countplot(data=training_set, x='Term')
plt.show()

# %%
sns.countplot(data=training_set, x='Home Ownership')
plt.show()

# %%
sns.countplot(data=training_set, x='Purpose')
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(data=training_set, x='Loan Status')
#plt.xticks(rotation=90)
plt.show()

# %%
training_set['Number of Credit Problems'].plot()

# %%
training_set.plot()

# %%
training_set.fillna(99999999)
# Out:
#        Loan Status  Current Loan Amount        Term  Credit Score  \
# 0       Fully Paid             445412.0  Short Term         709.0
# 1       Fully Paid             262328.0  Short Term    99999999.0
# 2       Fully Paid           99999999.0  Short Term         741.0
# 3       Fully Paid             347666.0   Long Term         721.0
# 4       Fully Paid             176220.0  Short Term    99999999.0
# ...            ...                  ...         ...           ...
# 100509    99999999           99999999.0    99999999    99999999.0
# 100510    99999999           99999999.0    99999999    99999999.0
# 100511    99999999           99999999.0    99999999    99999999.0
# 100512    99999999           99999999.0    99999999    99999999.0
# 100513    99999999           99999999.0    99999999    99999999.0
#
#         Annual Income Years in current job Home Ownership             Purpose  \
# 0           1167493.0              8 years  Home Mortgage   Home Improvements
# ...

# %%
training_set.drop(['Years in current job', 'Tax Liens'], axis=1)
# Out:
#        Loan Status  Current Loan Amount        Term  Credit Score  \
# 0       Fully Paid             445412.0  Short Term         709.0
# 1       Fully Paid             262328.0  Short Term           NaN
# 2       Fully Paid           99999999.0  Short Term         741.0
# 3       Fully Paid             347666.0   Long Term         721.0
# 4       Fully Paid             176220.0  Short Term           NaN
# ...            ...                  ...         ...           ...
# 100509         NaN                  NaN         NaN           NaN
# 100510         NaN                  NaN         NaN           NaN
# 100511         NaN                  NaN         NaN           NaN
# 100512         NaN                  NaN         NaN           NaN
# 100513         NaN                  NaN         NaN           NaN
#
#         Annual Income Home Ownership             Purpose  Monthly Debt  \
# 0           1167493.0  Home Mortgage   Home Improvements       5214.74
# ...

# %%
training_set_reduced.drop(['Years in current job', 'Tax Liens'], axis=1)
# Out:
#       Loan Status  Current Loan Amount        Term  Credit Score  \
# 2      Fully Paid           99999999.0  Short Term         741.0
# 6      Fully Paid             217646.0  Short Term         730.0
# 8      Fully Paid             548746.0  Short Term         678.0
# 10     Fully Paid           99999999.0  Short Term         728.0
# 12     Fully Paid           99999999.0  Short Term         740.0
# ...           ...                  ...         ...           ...
# 99990  Fully Paid           99999999.0  Short Term         742.0
# 99993  Fully Paid              44484.0  Short Term         717.0
# 99994  Fully Paid             210584.0  Short Term         719.0
# 99996  Fully Paid           99999999.0  Short Term         732.0
# 99997  Fully Paid             103136.0  Short Term         742.0
#
#        Annual Income Home Ownership             Purpose  Monthly Debt  \
# 2          2231892.0       Own Home  Debt Consolidation      29200.53
# ...

# %% [markdown]
# # Split training data between test and validation set

# %% [markdown]
# # # # Split Into Training and Testing Sets
#
# # Separate out the features and targets

# %%
features = training_set.drop(columns='Loan Status')
targets = pd.DataFrame(training_set['Loan Status'])

# %%
# Split into 80% training and 20% validation  set
X_train, X_test, y_train, y_test = train_test_split(features, targets, test_size = 0.2, random_state = 42)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (80411, 16)
# (20103, 16)
# (80411, 1)
# (20103, 1)

# %%
training_set['Purpose'] = training_set['Purpose'].str.replace('%','').astype(np.float64)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-039158ae723b> in <module>
# ----> 1 training_set['Purpose'] = training_set['Purpose'].str.replace('%','').astype(np.float64)
#
# D:\Programs\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# D:\Programs\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
# ...

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-353a0c218ac2> in <module>
#       1 sc = StandardScaler()
# ----> 2 X_train = sc.fit_transform(X_train)
#       3 X_test = sc.transform(X_test)
#
# D:\Programs\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     569         if y is None:
#     570             # fit method of arity 1 (unsupervised transformation)
# --> 571             return self.fit(X, **fit_params).transform(X)
#     572         else:
#     573             # fit method of arity 2 (supervised transformation)
#
# D:\Programs\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y)
#     667         # Reset internal state before fitting
#     668         self._reset()
# --> 669         return self.partial_fit(X, y)
#     670
#     671     def partial_fit(self, X, y=None):
#
# ...

# %% [markdown]
# # ML METHODS
#
# -  LINEAR REGRESSION
# -  RANDOM FOREST

# %% [markdown]
# ## Logistic regression

# %%
x_train = training_set.drop(labels='Loan Status', axis=1).values
y_train = training_set['Loan Status'].values
x_test = testing_set.values

# %%
logistic_regression = LogisticRegression()
logistic_regression.fit(x_train,y_train)
evaluation = fit_and_evaluate(logistic_regression)
